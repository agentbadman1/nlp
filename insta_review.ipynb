# %%
import pandas as pd
import numpy
import nltk

# %%
data = pd.read_csv('instagram.csv')

# %%
data.head()
# Out:
#                                   review_description  rating  \
# 0  The app is good for connecting with friends, f...       3
# 1  Used to be my favorite social media app, but "...       2
# 2  Instagram is the best of all the social media....       5
# 3  I love this app.. but as of late, I have been ...       2
# 4  Used to be a great app but there are so many m...       3
#
#            review_date
# 0  2023-07-11 23:57:07
# 1  2023-07-22 21:37:09
# 2  2023-07-25 03:24:58
# 3  2023-07-09 04:49:57
# 4  2023-07-17 16:47:04

# %%
data.shape
# Out:
# (210542, 3)

# %%
X = data['review_description']

# %%
Y = data['rating']

# %%
#importing libraries
from nltk.corpus import stopwords
nltk.download('stopwords')
import string
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
stop_words = stopwords.words('english')
punctuations = string.punctuation
import re
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\d2god\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\d2god\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
clean_data = []
for i in range(len(X)):
    text = re.sub('[^a-zA-Z]', ' ',X.iloc[i])
    text = text.lower().split()
    text = [lemmatizer.lemmatize(word) for word in text if (word not in stop_words) and (word not in punctuations)]
    text = ' '.join(text)
    clean_data.append(text)

# %%
clean_data
# Out:
# ['app good connecting friend family even potential business partner however recently experienced problem message portion app ex theme showing end present person end idk bug happened sudden nowhere page one private public besides occasional bug sometimes app website randomly say decent app',
#  'used favorite social medium app improvement made harder harder use find using le le recent terrible feature added make photo carousel autoswipe second way turn driving crazy tiktok stop trying also dark mode break time find environment background white white text making impossible read anything',
#  'instagram best social medium ig posting platform facilitates process getting one message world design functionality interface intuitive user friendly guide best possible option without limiting directing content platform responsive even remotely aware unique need ig know innovate improve presentation complex content',
#  'love app late problem screen background turning white longer normal loading keep crashing get notification click see moment go home page crash uninstalled cleared cache restarted phone nothing work please fix bug app',
#  'used great app many bug issue ever plus ruining user interface trying keep social medium platform making editing video app extremely infuriating like try add extra feature quite right way actually end limiting feel like fighting instagram every time want make little second reel',
#  'app glitching alot video play instead show black screen audio play either message theme keep going back default even changed stay tried delete reinstall still working done multiple time well restart phone nothing helped working',
#  'like app lot messaging part app frustrating sometimes get notification friend respond one time recently sent friend reel responded went see said reel sent gone end could still see sometimes send message leave app go back said never sent message wish bug would fixed dealt',
#  'eventhough sometimes work time quality video uploaded site suck well recommended video video resolution also lack configuration option recommendation like wanting verified account able manually change interest ability reset suggestion feed way site set also confusing instagram meta quality app better',
#  'sure point leaving review accomplish recent review regarding issue nothing done address issue video page short fully loading refreshing leaving black gray white screen fortunate enough see video short photo stuff day hope someone working fix lack response developer user matter',
#  'app many frustrating aspect theme work work minute stop message glitch look like message deleted refresh entire page happens whenever open app texting outside app hardly work send message go app sent twice notification glitchy stop restart phone randomly reason',
#  'complaint video calling feature small split screen love app use daily edit app given lot issue twice open say refresh feed tried uninstalling restarting app work also previous trouble logging though seems fixed know get work long fixed lol',
#  'ago noticed talk people background keep getting set back default color usually talk main people background different default go back change background would either go back default would change would last minute please fix tried reinstalling work friend said normal something wrong mine',
#  'love app everytime open ten twenty minute scrolling stop playing reel aggravating cause let scroll reload stuff never play let watch video saved story well keeping updated understand edit stopped working crash every time try get',
#  'fine update watch video post explore page hate clip done move next post esp post one slide move see next slide flippin annoying update get weird black border around video tap',
#  'say msg year none troubleshooting idea work annoying tolerable click black content creator tagged caption load tried many time several different accts non black accts opened fine tried force stopping clearing data uninstall reinstall restarting phone etc sure seeing actually happening seems deliberate need corrected immediately',
#  'better comment one long line mobile device whereas user could see text proofread sending always easy get point across one sentence please make ui user friendly also wondering drive picture come search window get many interest',
#  'app switch dark mode unuseable past week using app switch dark mode made text black background post unreadable app pretty much worthless unuseable sound like common need addressed many platform instagram letting go long yes cleared cache reinstalled whole work several time',
#  'even light mode sometimes app turn text white white read anything seems happen everytime click link someone bio go back app chat theme also see anymore would good turn autoplay feature since looking photo reel automatically start playing reel reel done scroll next post even though done looking picture',
#  'pretty good app use frequently issue lately one apps weird color scheme change background post clash black white see text another issue chat theme close automatically change back pre determined suck see color give personality',
#  'photographer web devloper graphic designer feel limiting use instagram aspect ratio set app respond landscape mode device also algorithm seems suppress post unless pay boost course never know info kept secret user still good app sharing photo potential reach larger audience good connect younger target market',
#  'easy use part good talk friend issue go home screen open another app instagram show recently used apps reopen sound bad really annoying happening instagram even reinstalling found fix happening even update',
#  'app open anymore attempt cause crash saying bug done everything fix restart phone uninstall reinstall app check update phone app cleared cache app continues crash whenever try open forced use web browser ridiculous',
#  'first lose ability use reel real indication upgraded app version clear cache nothing even scroll post without app crashing pop saying bug need addressed download new version developer create patch delete app use form social medium better',
#  'currently impossible edit reel app stop playing try edit save draft open audio longer available deletes video accidentally hit back button work disappears screen also becomes partially white black time making difficult read text',
#  'app honestly favorite social medias one reliably use many thing wrong hard recommend anyone fact screen randomly become half light half dark mode fact device get newer content note chat theme recently ability use song note also able use said feature nd account primary one',
#  'recently updated app pixel pro latest july patch app force close moment open open disappears reset device maybe get open get notification app would say time randomly close incredibly frustrating unbelievable sure operating system update recent update app judging date review feel like app update',
#  'instagram become super annoying use reel mistake story highlight still broken know fact common mistake isnt fix highlight music wont load freeze either like random one music removed either song work one another idk fix app man',
#  'instagram suck reason way many turn sound people story unless turned feed scroll start left like twitter instagram throw latest upload whether wanted see app becoming worse worse almost time delete like facebook video glitching',
#  'keep crashing ever since yesterday tried web version work fine rhyme reason started insta crashing trying launch app even went far removing app reinstalling scrolling couple second kick might banned explain able use web version hopefully get fixed soon',
#  'personalization location tracking make app slow frustrating use consistent level especially traveling outside original data coverage area said instagram considerable upgrade facebook every way absolute huge problem constant scamming soliciting bot people alike another incredibly large problem amongst community identity theft buying account specifically reel',
#  'see ad content people follow also changed back x week ago time format super inconvenient used able hold image editing see looked like move image go adjustment see looked like adjustment save image gallery image ie there black bar straightening showing side',
#  'formatting gotten worse worse explore page scroll smoothly anymore play random video underneath watching trying look photo read text based post super distracting understand trying phase photo literally photo sharing app thing work somewhat smoothly reel thats want use app make frustrated',
#  'updating review since many issue fixed save menu pop great addition let u choose save folder use nice le prominent cover screen want quickly save video move without picking folder get way maybe smaller menu would better',
#  'sure happening seems update update cause one bug top another currently story want load correctly today case add text sticker anything really one slide series add every slide go slide trash supposed go back original pull everything trash area replace frustrating time consuming',
#  'last couple week using app randomly change either white screen photo everything photo black screen black unable see word photo glitch sometimes found work around time app start scrolling sometimes really annoying please place attention focus issue well people mentioned',
#  'app used smooth functional every update seems introduce new bug rather feature keeping old bug point app longer functional example one specific chat inaccessible click app crash another example scrolling reel certain point scroll reel say reel unavailable app immediately crash broken essential feature',
#  'never enjoyed app though appreciate content decent way artist share art others life however think unreliable app incredibly glitchy may worth note specifically instagram format change dramatically whenever go different screen ex message could light mode exit home screen dark mode happened recently',
#  'change format week ago instead precise date inconvenient also update story icon big choosing picture post leave app example go gallery check picture automatically reset chosen picture choose unclear draft post also draft reel folder keep appearing disappearing ad one another often',
#  'many issue think every update mess something else use ig mostly video chat sudden connect bluetooth longer full screen person talking get full screen two half photo top trash sound best room anyone else since staying connected bluetooth almost impossible please fix would love go back normal video call',
#  'app really throwing garbage push reel hard get work right scrolling close app click different one later next swipe one already seen exact order also tell swipe reel watch one couple time giving tutorial use also posting image glitch edits crop weird matter',
#  'annoying crashing lot lately freeze recently liked post setting missing used lot gone hoping bring back let save post edit changed post show many week ago exact date also message work sometimes show day someone sent',
#  'word something went wrong please try haunt sleep reel editor disaster fairly new powerful phone device issue plus seen reviewer problem freeze soon start anything adding clip trimming music text transition etc much money meta much push reel algorithm excuse trainwreck',
#  'disappointed trying upload multiple picture got edit move longer centered cut get part picture get half inch vertical black line left side especially annoying spent much time adjusting picture find shifted everything fix work go right back cropped',
#  'since last update instagram story creation bugged specifically layered sticker function working correctly choose subsequent sticker forgets image scroll back top previously remembered also add sticker copy onto story making multiple story overall story resolution seems lower well least come adding text video gifs text',
#  'constantly declining best way describe experience instagram entire chat deleted notification never going theme appearing disappearing video send receive often cannot played corrupted download many issue dm sometimes audio keep playing close app sometimes app double post comment sometimes let post start',
#  'every update make app worse take away good feature keep adding unnecesary stuff instagram lost touch everything became reel used nice see picture friend posted see random reel suggested reel repeated reel ad app lost intimacy user feel like overcrowded concert something cant enjoy really sad tbh used app decade gotten progressively worse',
#  'necessary evil unfortunately lot connecting relies ig nowadays app suck multiple account app horrible business creator artist normal user basically matter kind account app terrible user friendly algorithm suck reel dont even play half time edits one reel show others u cant scroll chronological feed anymore button always move change basically tiktok',
#  'changed layout share video pic friend layout perfectly fine way gonna make download previous version app stupidly changed like new layout sharing video want share story option top list format like however long want option bottom screen need chat head displayed front center please fix',
#  'app full glitch screen turn white see anything else used love app fun beautiful picture became video really annoying made hard nearly impossible find relevant content unless want see content account huge following luck made nearly impossible small account get noticed taking away recent option',
#  'share multiple photo someone even look save show stack photo inaccessible messaging barely provides notification refresh go back feed refresh feed message refresh sometimes full closing opening app way fix',
#  'piece junk software would love give zero star whatever latest value added update appears redact every picture post refresh photo show blurred let manually refresh log access user option workaround found delete app reinstall every time want interact free data mining sink hole demand refund',
#  'constant story notification despite turned app turned instagram notification first time year relatively recently incessant stop sending story notification every hour two terribly annoying turning notification garbage app allow casual user algorithm want addicted zero star',
#  'many ad app great see advertisement every set story every rd post newsfeed point report every single one show often ready stop using app see content prople follow instead ad promoted content recommended trash',
#  'forced swiping post went away back reason really hate feature dictated system long look photo acknowledge tap stop timer auto swipe extra step want begin please start surfacing option view content interact please stop forcing specific way',
#  'app always glichy late message suddenly showing like deleted used troubleshooting seen restarting phone loging back checking wifi switching data ect nothing brought back cannot text friend app anymore please fix',
#  'customer service non existent last account got hacked photo retrieval method app use analyze face compare photo account return match problem app would crash process pretty new android one reach start year previous account',
#  'would month hit reply reply message longer automatically enters name replying memorize type bad enough sentence line wrap feature longer work reply keep going one line forever make editing impossible checked setting yet find setting last month',
#  'edit nice borderline frame around picture keep straight adjusting size picture preview section would nice display identical like display see would make easier visualize sent feed hope consider',
#  'updating search could user friendly filter length adjustment story flash past sec used least give three update add music add length story however music search story awful suggesting music far line would ever use update suggestion going make suggestion least give u thumb option',
#  'good concept photo adjustment tool used really good somehow work well used app shockingly buggy especially posting multiple adjusted photo one post bug often come go repeatedly different update noticed eventually getting fixed new one always pop also want feed show mostly people follow many new suggestion',
#  'important use modeling otherwise would use buggy app text disappears post reason message get sent multiple time important feature completely missing example post edit carousel remove change order add collaborator ig crop image matter add collaborator post bug complaint',
#  'color scheme constantly turning white done unable select anything conversation friend constantly disappearing photo tried download become blurry delete restarted phone several time try get correct avail ready get rid app',
#  'working well could ask well seeing note day ago theme reset default longer see limited one lost entirely one issue alone would issue many inconvenience pile top enough',
#  'overall fine app work feature absolutely try start saved post folder multiple people allow feature also available separate account like one account ahead term update oh yeah also uninstalled reinstalled app see would fix thing tried pc also feature seriously need fixing',
#  'full glitch make reel get traffic reel feature many issue done whole app lost hour work reel warning whole reel gone draft posting gone kind thing keep happening worth headache imo',
#  'reel icon disappears almost daily un installed installed pretty much daily month contacted support time response phone internet app date running fast constantly lose reel icon ability scroll reel see either find reel story back home screen watching every reel un install app happening frustrating',
#  'recent update made hard anything would originally get app posting photo story instead replaces convenient button shopping reel one wanted wanted shopping advertisement use ig yet someone development thought good idea push updated',
#  'update uninstall post load except make video cover zoomed even profile page profile look video cut zoomed normal send multiple photo someone appears stack even opened refresh constantly see new message explore page auto scroll turned fight auto scroll even consume content',
#  'still log android app actually work using finger enlarge picture story often make pic tilt one side accidentally touching top screen cause app scroll way top stupid add refresh button actually see time use share button risk losing place app refreshes also instagram facebook special app installer hate',
#  'recently issue app allow repost post reel photo someone else explore page feed people follow thing able currently post onto story anything camera roll tried updating current update uninstalling reinstalling app logging account well hopefully one dealing issue currently',
#  'agree negative review right share anything story posting multiple photo different size time nightmare ig decide randomly crop whatever want reel editor reel remix joke even bother anymore always freezing posting error looked fine draft think would easy issue address would make priority super frustrating',
#  'alright new review option save post camera roll turned still save post longer give option original post recent update instead save original photo turned several time still save post camera roll need multiple copy photo phone clutter space need star fixed',
#  'editing review huge bug dislike actually two first worst wont get message send later vise versa could send msg disappears reappears later next bad would make photo cant viewed get rid notification person',
#  'mulfunctioning lot lately biggest issue story creation choose multiple photo try make separate story caption stamp whatever added one slide repeated every slide delete one fix original since deletion others affect original slide hard describe exactly happening new problem bothersome',
#  'mediocre best even happened app conversation randomly deleted entirely inbox right latest update tried logging back deleting cache deleting redownloading fixed view someone story since keep switching something else many time even story pause reel video either see date posted dark light mode many time time please fix',
#  'story share option disappeared one account phone uninstalling clearing cache nothing post randomly zoomed posting even perfect square tapped fit aspect ratio multiple slide anything first one could screwy number way also getting notification app sent message',
#  'got new phone decided update instagram even though old phone turned see anything typing live trying respond people also cannot pause longer video tapping pause button also cannot use slider bar go forward backwards longer visit app buggy obvious developer care collecting paycheck',
#  'draft never save go make post picture usually get stretched cut reel draft never save either cant see view story insight rarely load whole note window disappears also close play last watched video sound constantly even become unresponsive large amount glitch trying post anything instagram barely function time hope get fixed',
#  'one second something next app bugging age ridiculous option post story quite literally disappeared within second matter many time restart app still gone notification also spontaneously stopped working cannot life fix',
#  'app many issue right change dark light mode randomly area read text white white black black sometimes music system also practically unnavigatable trending section anymore get song reel made recommended great growing account speaking cannot grow account anymore current change place better already celebrity seen',
#  'worst app actually try edit post reel insanely glitchy constantly tell something went wrong make force stop app try take good minute post second clip constantly trying get edit without glitch app around long expect much better',
#  'constantly go app stop changing theme white random part app making impossible read see anything text also white super annoying tired ad annoying start feel intolerable time recommended algorithm also atrocious like something mean continue show reasonable amount want whole feed one thing',
#  'phone mysteriously running storage found app slowly ballooning eating almost gb data right one hundred gigabyte cache cleared easily actual data requires resetting app fresh reinstall insanely ridiculous absolutely way recommend anyone using app going eat much device storage',
#  'read edit history since last year around time trouble instagram auto updating setting update automatically turned past month several account problem action blocking reason causing delete one account remake lost multiple feature account like holding save reel save collection use lot',
#  'general good app however seems frequent micro update installed app overall functionality even w opting beta result frustrating user experience end either dealing bug unannounced change ui make wonder issue app figure new process preferable change consistently announced via pop ups already',
#  'app always issue confusion continue get worse today simply unable upload reel matter two video posted notification stuck top page first attempt reel stuck loading half hour rebooted app phone still reel load get end stop app drive nut sometimes',
#  'literally like different layout kind gamble one get got multiple account phone different layout feature also constantly buggy slow like trying send someone post nothing show yeah lot worse app considering popular',
#  'work great glitch often time reel hang whole app fail load change screen name load new reel rhyme reason sometimes work sometimes failure failure make wanna use share photo video',
#  'moved u spain first day fine got notice location data stored changed clicked agree use app page glitch open toggling blank white page pop say set thanks hit back arrow say continue reviewing leave nothing review blank white page uninstalled reinstalled x app say recognize cell',
#  'app getting worse worse reel pushed ever way stop reel sent dm autoplaying lag app stop completely crash making impossible read dm happened click video play reel saved bookmark choose folder go sending image dm broken work half time',
#  'say fb linked post music option country reel impossible anything sent email bug request since beginning may got nothing back tried uninstalling logging nothing frustration using business stuff go somewhere else',
#  'creator account newest feature appointment stop reminding making appointment option want begin account problem click x reminder keep coming back get rid also app keep crashing every time try click someone post story',
#  'small artist app love connect community however app screw u small creator new update make hashtags virtually inaccessible make almost impossible find small account also algorithm boost reel save draft reel audio disappear save go search every update add bug',
#  'bring back recent hashtags way search find new smaller account actually engage topic interested instagram reel reposted tiktok ad wanted watch video using photo app also huge increase bug photo posted literal glitch app crash blank photo story list go app becoming unusable shell',
#  'every update app get worse artist creator force make reel get content seen tiktok wannabe completely destroying photo sharing aspect focus top content inaccessible starting without huge following ignoring user speak change long time',
#  'reason particular account cannot longer see message signed logged deleted app reinstalled even restarted phone nothing issue get notification messaged click say cannot reply convo keep loading work perfectly fine account well laptop get',
#  'app date yet ever come across video video always cut right watch full format reel upsetting nothing fix format app get repetitive seen everything feed make tiring',
#  'issue app right work fine issue love dark mode insta keep glitching back partial light mode make word unreadable point either exit completely go back go setting change annoying glitch currently fine',
#  'app functed properly month reported problem longer reel tab cannot open reel link sent text email cannot unsave previously saved post reel never got help problem never fixed tried using beta version uninstalling reinstalling app even logged another phone nothing work hopefully instagram look problem soon',
#  'using instagram couple year lately laggy glitchy also nice could move end call button towards bottom screen call coming need leave instagram call nice could move end call button towards bottom screen',
#  'constantly deleting clip reel draft disappearing whole reel saying posted start scratch absolutely horrible wit end decided leave negative review today consistently issue app today created reel dressed makeup transition event attending decided save clip moving absolutely nowhere reclaim lost video star',
#  'used love instagram last month unable scroll reel show explore feed anymore past day note disappeared except like one account tried logging uninstalling reinstalling app even restarting phone',
#  'whatever reason instagram like reformat image post end picture center final post frustrating look totally normal creating post shift uploaded pain trying edit posted work either',
#  'app fine time made like reviewer saying option adding story either gone go use one moment working fine next gone get back tried different thing thinking mightve phone nothing worked switch older one used utlize feature back might glitch device',
#  'ridiculous update still constant bug past month almost every stinking time tried post story unknown error make mistake sending message get back main feed literally impossible restart whole phone get revert back get together',
#  'use app communication friend mostly messaging stuff recently everything glitch randomly crash part screen turn white open message ik sent send notification message sometimes recently problem tried post picture would glitch sure happening recently used use without problem kinda mess',
#  'even worth time take post thing anymore buggy app gotten make sense owned one wealithiest corporation world yet functioned better forget editing anything app editing software glitchy freeze randomly crop photo even think resizing mention anything reel story completely unusable',
#  'latest update broken sound setting story default sound rather making extremely annoying browse listening anything every update instagram ruin sound setting make story play full volume default abysmal user experience use phone music sometimes want loud video start playing public setting broken fixed broken fix',
#  'work great lotta time amount time redownload reset godforsaken app sending message letting see absolutely worth gone downhill since first got many time full wifi service let see message anyway mention theme resetting time',
#  'video play sound unless click go whole video watcher scroll listen half time little sound button bottom right corner pressing take video watcher rather turning sound like used idk intentional error instagram hope intentional would stupid decision please fix',
#  'like app overall though would like make recommendation make even better nice pin highlight profile really like idea highlight hope guy expand itd also cool add feature adding different song music multiple photo',
#  'latest update messed everything video appearing stretched message appearing dm send person receives see glitch glitch scrolling reel comment previous reel appear next etc absolute mess please fix',
#  'many issue lately seeing million post page showing others stupid algorithm additionally issue stretching image choosing crop also issue image drifting far side leaving mysterious black border one side posting lately message unsend even refreshing home page bring new post new message despite getting notification',
#  'reel issue frustrating editing reel kicked reason reel painstakingly trimming disappear without even saved tried several time thing keep happening brand new phone checked ig update etc still thing ugh',
#  'unable disable double tap like anytime tap screen result potentially unintentionally liking image want like medium take time select heart icon rather straightforward methodology need shortcut like medium post seems lacking user experience testing',
#  'latest update reason whenever navigate app notification go light mode partially post featured comment light rest dark black type making part page impossible see part bright give headache way reset back dark mode force close app reopen reset post different level annoying',
#  'think instagram great platform push reel much also really need fixed even post multiple photo everytime edit first photo move onto next glitch crop previous photo edited unpostable post pic computer fewer editing option instagram website compared app supposed photo sharing app even post photo properly',
#  'app super glitchy constantly something going either show text sent people photo open definitely need bug fixing update update staying dark mode like set glitchy never stay checked update like time nothing also getting new stuff need serious fixing',
#  'show chat message like supposed message see online desktop site show app whatsoever even notification multi photo post tendency second slide annoying x week ago format cool scrolling buggy app reel feed especially online desktop version',
#  'app stupid even post instagram story anymore post picture editing done whatsoever add multiple picture story music choice story want upload stuck uploading long time exit app come back see story uploads completely deletes everything going used really active instagram reason',
#  'texting friend today sent photo told update app order look updated app everything looked normal however started using home noticed longer share post explore page anywhere matter story went direct message took ability see active quick glance longer put short message profile please stop updating',
#  'reel first force u using make work save life clear one reading recent review never issue uploading video post reel havent able upload even one clip day view reel fine also post story tried recommended fix nothing worked',
#  'year wanting finaly save reel specific save catalog reel feature day one day vanished saved became set like old version updated app multiple time yet still forced older version main account account feature fix app zuckerberg',
#  'editing uploading reel nightmare many glitch editing process lost reel worked hard work error message lack connection painfully frustrating since wifi get error code mobile data everything capcut upload reel issue fix gd app',
#  'instagram absolute trash refresh page haunt uninstall reinstall app one many time even letting sign account anything take refresh page screen open app lost many account hardly even anything lose much work time spent thrown away like please start listening viewer downloaders fix app star',
#  'fine like time work would expect go upload edit photo using slider edit photo try give seizure flashing bunch showing photo look also edited whole photo upload actually uploaded like photo uploaded previous photo somehow two photo normally star really seizure warning',
#  'hell happened load vids add music picture black image loading multiple image failing many way first try edit either stretch image properly crop try edit center image tried remove app completely cannot log original account code sent sent twice phone twice email toy broken',
#  'instagram long time bug issue ridiculous cannot share anything story able share group dm gone every section setting phone app uninstalled reinstalled cleared cache nothing changed old phone app completely updated please fix',
#  'something changed photo skewed sure happened attempted post photo last week today move filter section entire photo stretched blurry problem photo since post elsewhere without issue please fix thanks',
#  'update still many bug could fixed restore archived video show profile photo instead whole video date stamp week actual date would think week would transition date posting photo add music likely making good experience',
#  'become even inconvenience lagging point becomes nearly unusable getting phone unusually warm bit never past save menu showing covering screen choose save post pretty obnoxious chat worked right long time entire conversation group chat simply load half time friend issue chat',
#  'recently lost sound video year ago place saved instagram reason ig removed sound bummer ruined artist poet one hear earlier work super bummed updated latest version app',
#  'app two bug sure one bug new restriction first bug posting multiple photo impossible keep messing one photo position matter second disappearance add post story option seem share public post friend story',
#  'going insta right message sent right middle good conversation even see feed page anyone el even watch video feed like insta shut tried force stop app refresh work still thing',
#  'removed date posted post show term many week ago hell think time term many week ago answer one put date back using platform journal sort keep track event photo change huge let might find different platform use keep way',
#  'many glitch gone downhill ever since facebook bought often let post story click external link come back app dark theme turn light read text shopping tab completely useless app meant update longer share post story feature button moved others mine simply absent',
#  'new scheduling feature fully work work try upload sometimes nut often get error internet working tested internet fine reel video scheduled show main feed even though option turned instagram force schedule longer second video within app otherwise cut thing fit format meta business suite',
#  'edit post though app still many problem still instagram let post anything tried closing app restarting phone still unable post messaging friend problem well way often message take long send even send person messaging always recieve',
#  'overrun ad algorithm feed sponsored content direction app pushing away year likely uninstall get worse wanted see content selected garbage insta push especially see thing multiple time single session',
#  'love instagram used year world longer reshare post story fundamental part experience instagram authentic connection exposure based follow botched algorithm also click log button signing business personal profile irritating waste time please fix bug',
#  'lot glitch error mainly loading certain thing say error something wrong connection even though perfectly fine also random bug chatting suddenly going random person trying text current person sure problem recently hopefully get fixed',
#  'many issue app longer music option color get desaturated try upload post need reedit app issue story failing post app crashing day may update repost story whether someone else post reshare anything tagged restarted even uninstalled help reappeared day later disappear',
#  'unbelievable let reel editor constant loading issue often edit video limitation currently completely locked app clearing cache uninstalling reinstalling try help issue truly mind boggling something already perfect astronomically inconvenient issue',
#  'giving app low score infuriating always bug glitch deal app almost never working completely smoothly would think many feature update new thing add would take time address issue always new one popping care trying keep tiktoks ui maybe app would work good please get top bug',
#  'insta constantly rolling update make life inconvenient app constantly remove change feature ignoring bug glitch app gotten slower frustrating year point consistently think ditching app altogether use useful tool news connecting small group friend rather entertainment tiktok million time better avoid insta entirely highly advise',
#  'ever since started pushing reel anything else app went downhill reel constantly glitching never get fixed post content would help page yall want everyone reel try compete tiktok make actually work glitch glitch record video talking audio delay full second last second every audio always cut audio saving draft app suck anymore',
#  'creator account need step finish setting reason final step post something step still complete suspect reason note every single account main layout get confusing constantly move stuff fix ill happily give star instagram',
#  'reel problematic take entire feed show half screen ever since reel became thing app glitchy see post till day later know could click top right corner choose see post follow wish could keep default option depending choose well would nice option turn reel great app reel',
#  'ofc love instagram everything problem abt year really need fixed whenever try posting story post whatever always say unable load image even show picture post anything without clicking recently got updated even show option anymore please please fix soon possible thank',
#  'hello overall instagram good social medium platform recommendation relative viewing experience great like add whenever want feature story add select multiple image time sorry wrote felt like would much technical problem overall instagram good social medium platform bug fully functional',
#  'love app new feature note dm reply reaction available account app show updated created new account phone feature available unistalled app installed several time result contacted support center nothing changed received reply shame',
#  'used love app lately lot issue lot bug lot time open app immediately close keep happening long time app frequently switch dark mode light mode reason without switched often image sent load also issue algorithm since removal recent post option hashtags increasingly difficult small creator use',
#  'suggestion whenever try put something story android device quality picture video decrease although setting high resolution still see drop quality picture guy solve issue much better experience android user thanks',
#  'harder find old photo pointless new change x week ago instead actual date make even difficult look back old photo make sense add value think need way better browse post even something like old photo map great becoming increasing problem one post something would drastically impr',
#  'social medium app use daily come plenty bug repeated unrefreshed story unresponsive draft light dark mode glitching often even clearing cache restarting app really annoying go algorithm omitted feature seem longer prioritize smaller creator platform continue use keep friend would great could fixed somehow',
#  'great app something driving crazy using instagram tablet every time reel come giant black bar appears right side screen happen beforehand incredibly ugly please change like move video middle screen like hard come ugly',
#  'instagram really good great form social medium reason old account got disabled instagram reenable another problem whenever scrolling reel liking saving video sometimes like video go save screen freeze becomes unresponsive save quite annoying since lost video interested since real come people following',
#  'started well enjoying experience set page dog longer due bug post reel tried using report problem installed app signed cleared app cache yet zero response anyone nothing seems work one seems care disappointed',
#  'app crash switch betqeen dark light kode opening certain page explore page long wait time show post time recent update highlight longer show two account switch always get notification red dot say notification nothing app unusable point frustrating edit unable post reel video even report bug',
#  'many bug every new update reel option centre home tab seen anymore cant even scroll see next reel really disappointing please fix edit issue fixed reported problem help section still nothing happened yet tried everything reinstalling app clearing cache luck really disappointed',
#  'used fantastic awful used automatically save photo uploads folder phone storage despite ticking option top often repost picture least time photo completely loaded visual glitch like bad attempt andy warhol portrait frustating',
#  'dear instagram message button option poll option available instagram account updated app latest still cannot find poll option well long time since complained message button option step taken request kindly look option make available important content creator interact audience thankyou',
#  'android user july pm hello thank returning date better format another glitch noticed ribbon end lower right corner photo gone visit profile save photo folder feed present hope get fixed convenient tool bookmarking photo inspiration browse profile',
#  'whenever upload post rarely always seems glitch either zoom move image crop photo app oftens crash whilst make post well also find annoying ironic creativity photography app yet cannot alternate portrait landscape photo finding going facebook job role instagram used play',
#  'really hate update carousel automatically advance work want spend second looking image use instagram quality photo content whatever designed goldfish concentrate something longer least make setting allow turn',
#  'everything app functioning recent feature present except ig note feature updated latest version tried uninstalling install changed location accurate one phone updated latest android software still feature came people know instagram life area feature yet mine hope fixed thank',
#  'used really enjoy app recently glitch cannot seem solve time upload video post stretch video playing happening month tried different data different setting phone etc however must upgrade never used happen make post look clunky unappealing video second delay stretching playing content',
#  'work time issue make hate app little everytime try log onto app crash saying bug uninstall reinstall work temporarily minute go still crash issue account app please get sorted',
#  'bother using app anymore moved tiktok weird thing video e g thumbnail upsidedown despite snippet video refuse render freeze editing video go black ultimately show stuff feed care change order see thing ad also repetitive',
#  'leaving app used fun place could scroll pas time nowadays ruined reel ad get next image content matter much try train algorithm show image accidentally like one single reel get next day stop trying mimic tiktok also way many ad like every th post ad annoying end wasting way much time every time',
#  'instagram pretty great still many bug using oneplus nord instagram pre installed sometimes comment post keyboard overlap comment box see typing also issue select particular reel reply reach dm issue around long many device including mine hence star rating',
#  'unable open account couple day sent feedback twice issue resolved yet also tried reporting problem app many time problem getting updated tried logging using different device reinstalling app changing password clearing storage cache restarting phone etc nothing helped response team either',
#  'country supported latest version app still messenger update edit getting worse worse put image song android message sending received reinstall app sometimes order get photoreply sent edit glitch time load highlight music lyric slider break video turn still image edit okay nvm',
#  'experiencing countless bug recently tried upload post least time app kept crashing editing would restart edits beginning every time sometimes clicked editing menu recent edits discarded finally able upload post took minute upload although might due internet picture came looking wonky',
#  'literally glitchy buggy app ever used think app built posting picture would least successfully nope seemingly abandoned picture favour video much better either even application worked barely algorithm executive decision loudly protested community deaf ear amazing artist community would delete app without hesitation',
#  'highlight sound tried reinstalling instagram still people still hear sound highlight hear sound reason please fix also wished selection music hope able select longer second music second short duh also ppl mention story add story anymore',
#  'app getting worse story save button buggy someone tag story want repost save button disappears save gallery music stoy still blocked region music reel also messy get started favorite feed would like account would newly created account main one reinstall update helped far',
#  'one favorite frequently used apps lately running lot bug application automatically change mode dark light text remains light nothing visible also encountered fact sending reel one person automatically sent people update problem reel dare',
#  'app getting difficult use constant ad recommendation last day open app without shutting immediately tried restarting power cycling phone uninstalling reinstalling app clearing app cache dice since even open long enough send report guess bug report',
#  'glitchy getting worse started video photo distorting last year sliding one side posted could see half image use another app crop pic posting ig today post video keep telling try another tried also tried reinstalling app really frustrating get started glut advert appear want able post see connection content',
#  'instagram great app overall user friendly interface engaging content keep hooked however small glitch profile photo opening upon clicking minor inconvenience fixing issue would greatly improve experience fantastic platform sharing moment connecting friend keep good work',
#  'app overall pretty good packed ton cool feature top regular social medium one note section dedicated reel ad big deal affect experience however recently experiencing lot bug sometimes go app via notification even general come dark mode annoying especially night thing also struggling load pain still recommend',
#  'mixed experience app one hand provided easy option share edit visual content really liked hand one day blue blocked posting reel get feedback long zero support report went unanswered left disappointing feeling',
# ...
#  'app keep closing whenever try access say everytime instagram keep stopping tried everything could fix nothing fix also force signed another device used another account worked fine account get fixed decide use app',
#  'currently buggy right stuck light dark mode search music show random result nothing searched also forgets edits posting batch photo basically risk trying edit posting one time even product test',
#  'past month news feed freeze update feed follow reported multiple time never get response found work around view new post frustrating update automatically done everything try fix problem',
#  'app going downhill fast especially artist algorithm favor reel taking away made instagram first place top hashtags work smaller account really get see top top recent look reason look tag try find lesser known artist much anymore change review stuff get resolved',
#  'couple day ago glitch displaying part ui light mode even set dark restarting app usually fix temporarily next time open happen first thought maybe phone weird looking recent negative review sound like lot people issue super frustrating please fix asap',
#  'messaging app simply terrible message get sent regularly disappear sometimes appear hour next day sometimes gone good even multiple update fixed',
#  'log issue via android receiving kick back message say unexpected error try later message day tried uninstalling app reinstalling app message appears going incognito mode sign online good experience truly hope issue resolved soon possible business owner connect promote business',
#  'page change dark light mode set also becomes half one half screen dark mode light text also becomes unreadable edit problem fixed also issue tag post make difficult noticed especially artist like',
#  'instagram please fix app brings lot problem even load image since yesterday uninstalled app suddenly brought problem started refusing load image work properly also respond anything even log something else still brings bug problem please fix app right',
#  'feature really excellent wonderful like app connecting new friend social event like follow idol inspirative personality knowing thier day day life seeing story reel etc feature one problem use extend notification pause hour hour app bravo',
#  'many bug going lately trying post video story couple day freeze crash tried updating still nothing working expect unknown app instagram fix',
#  'glitchy thing appearing update option side bar appearing seems white text white tried turning night mode glitch resulting white black banner screen music also doesnt play scratchy uploading photo video saving edits either',
#  'never issue instagram recently tag feature recent post anymore top post plus checking video reel audio seem play rest video past top one sure shadowban issue yet another bug app becoming le friendly small creator suck',
#  'instagram working long time one day next receive new post new story new message said instagram might crashed deleted data since even see login page give josh error page available right updated instagram far problem solved yet',
#  'remember update apps instagram really need fix someone sends multiple photo actually view two update ago broke saw another update review stating thing well still broken view go back single photo shared scroll latest one made look fancy turn different direction could make someone actually view darn photo',
#  'app keep crashing open app tried fix even uninstalled installed couple time still keep crashing launching app pls fix',
#  'love much social medium app use almost every day able meet new people interest interested thing people communicate ig apps people known whole life love algorithm pick interested connect like minded people',
#  'instagram fine nowadays feature getting worst every passing day able reply someone text swiping text right side valid text used better hope get feature back asap need also updating instagram try unique spoil good u comfortable',
#  'new creator picking momentum notification feed stopped working kristin account way fix way contact support missing important action chance connect audience really slowed progress need way contact support fix issue issue personal account professional account',
#  'last update hurdle installed almost time every week iam unable upload reel account whenever see update show update pending time week mailed support account setting find solution irritates delete account open kindly needful continuing account thank much',
#  'know suddenly share anything storie button disappeared gone absolutely nothing completely restarted uninstalled installed issue persists really frustrating day think target specific user friend still post story normally',
#  'thread caused insta crash dl thread open insta prompt meta page crash allowance crash report one thing dealing white another dealing reel edits hash tag recent fact even open app worse garbage',
#  'recently switched personal professional account nothing issue longer syncs facebook share anything story even post uninstalled reinstalled app reported bug several time frustrating trying grow business online presence could stayed personal bother metric feature',
#  'account well year still received reply option message reaction option despite reporting updating tried using device well still luck also tried contacting developer response issue would thankful issue fixed soon possible',
#  'excessive suggestion understand ad used pay app suggestion seeing suggestion followed post absurd excessive especially since turned suggestion like many thing facebook deception',
#  'use great app always glitch trying post story allow see girlfriend follower list done anything stop seeing therefore consider star real gift possible give zero would done hope message read application back app loved leave another one',
#  'instagram app keep crashing opening account account working perfectly account reinstalled app restarted phone well please help linked thread account kindly guide edit tried phone well app crashing phone well logging account',
#  'sure last update white background see writing font color background almost get migraine easily longer able dark theme going huge part decision continue using app bad move instagram',
#  'ui become unintuitive year especially reel like others reporting editing photo riddled bug right including adding white black space next photo squishing stretching photo etc make posting simpler wonder everyone going apps',
#  'little app would freeze minute tried sharing something story eventually would let waited reason even option share post story bug happen like week half getting incredibly irritating',
#  'yeah bug time ruining experience scheduling system working tagging system messed dm breaking newest one see recent post new update frustrating interact community want view unique content rather factory made stuff keep getting thrown face',
#  'security feature app worst know least follower hacked locked completely account user uploads content would like option upload content aspect ratio option',
#  'feature working properly lot bug secondary account audio remaining even changing page feature one account another even though type account also video call working properly ringing showing background',
#  'horrible ux changing time full glitch started hating app bottom heart thing take minute take basically audio try add reel unavailable open draft post recent algorithm new tab hashtags top top recent also way find ordinary people influencers stop useless upgrade fix ux issue',
#  'changed way reel work individual video line thing watch instead showing one recommend succession like get really annoying trying look content pertains',
#  'idea wrong song highlight play tagged someone one story highlight yet song available mine idk going',
#  'app us camera location way many time eventough havn done anything requires camera see permission usage android sometimes catch green camera icon top browsing',
#  'recent issue instagram annoying others much saving camera roll turned work still photo saving gallery getting really annoying especially others like use tried everything nothing worked maybe android samsung thing',
#  'truly love app communicate loved one constantly working lately log log work minute turn white see anything please fix problem give star',
#  'would give star since last week hard time posting story feed take forever uploaded posted worst would prompt error post please fix asap install uninstall reinstall app thanks',
#  'welcoming easy going professional love idea holding international gallery instagram great starting base create release inspire becoming inspired classy right amount community hashtags recommend app anyone loving encompassing demographic artist influencers personal life',
#  'ii using app since pretty satisfied however almost year still updated latest feature note stuff even though reached instagram reported problem month ago still received response mistaken',
#  'hi first want thank good application suggestion guess may solved problem many people create folder save section heading sport cookery program training etc user give user ability create folder organize photo video help u lot find desired video photo saved picture section',
#  'experience instagram great far issue around sudden inability access account result deactivated leaf one edge constant worry losing one account reason hear take eternity rectify even account owner innocent misunderstood bot algorithm thing also frustrating nigerian also eligible shop overall great platform grow one business',
#  'week instagram opening phone soon try open close automatically tried everything updating time force stop app clear cache everything nothing seems working frustrated disappointed bug please fix quick',
#  'nothing annoying watching video whole time prompted swipe see get know work finish one one first know locus gnat finish video without bored needingnour fix next thing gahhh',
#  'latest issue annoying many day problem resolved yet watching reel swiping app would crash randomly sometimes two reel sometimes happening frequently app keep crashing alot tried u installing reinstalling left beta testing also still issue resolved everything else device work fine except app',
#  'worst app hand think could get worse numerous post shoved left side screen narrow stretched format follow buttoms fill black void tye right make video unwatchable worst thing ig ever sell zuck',
#  'app going downhill continuous error bug dumbest thing pic video sent get instant greyed without clicking notification stopped working checked setting reset stuff reinstalled cache cleared etc issue continue recent issue certain thing work either could score zero would',
#  'edit since today business account bugged upload reel single post single post even appear profile either add one best performing single post missing uploaded new one test know old post come back new post missing nowhere found tell thread app messing business ig account pain',
#  'want account even common courtesy communicate going half time gave someone compliment culture way got acct suspended good explanation instruction get back lost ton follower potential follower work opportunity process networking found way back thanks still boost organically explore like',
#  'worst ui move delete button story bottom center corner wanted move text story got deleted stupid ui also crop option story poor search search work single word search content multiple word scale one pic pic collage also react way tap post add story screen add avatar need switch post outline frustrating',
#  'new update suck keep action blocking nothing say done wrong give end date update new update cause glitch everywhere leave thing alone message coming carousel photo coming black happy app anymore',
#  'open insta account app immediately close say instagram stopped working already tried restarting phone uninstalling still work try open different account app work please fix',
#  'absolute trash simplest thing work friend sends link open take reel section start playing algorithm content better',
#  'new tag situation inconvenient unnecessary change harder time discovering new account every new change seems make le user friendly small new account never gonna able grow also seems like story broken group upload story copy text music first one applies rest manually remove even afterwards text still bottom small',
#  'edited finally got feature wanted waiting year nice like app instagram social medium app use edited give everyone feature like new update switch see people follow choose favorite take priority like able respond message emojis like people crop video story',
#  'apps format gotten worse worse past month could immediately send meme stuff anyone friend issue select people want send hit send would completely fine new send share ui janky heck whenever try go hit send sometimes would go select person underneath send button intention sending',
#  'used great app used bug recently even put story post take hour put story keep freezing even open damn app literally open shuts right away',
#  'hey instagram iam teenager yo lately inappropriate ad sexual element popping instagram homepage ad disturbing inappropriate ad widely circulated seen teenager minor around world tried report block account spread thing think ineffective ad still popping homepage instagram act fix soon',
#  'cannot change name app web version go edit profile tap name brings blank white page nothing ever happens something new break every day lol also horrendous amount ad even scrolling person profile ad disgusting ultra',
#  'edit since latest update working much smoother ability edit video android adjust clip speed nice ad overwhelming thinking hoping thread check',
#  'tired seeing ad first every single time open app want see people follow ad hate new photo sharing format chat annoying displayed cluster sending time please bring back actual date post many week ago posted dumb',
#  'fun view post instagram continuously problem weirdly crop distorts image upon editing sometimes posting despite manual resetting often post time image actually post without automatically cropping distorting half image cut black frustrating dissuades using instagram',
#  'instagram good problem facing reel coming repeat repeat reel glitching heated phone setting understand updated open instagram checking friend aacount caption seeing dark mode looking white mode hate white mode fix problem instagram worst day day',
#  'everytime k try post picture always come glitchy sometimes discolored going almost week still stop updated app logged back uninstalled reimstall app turned phone turned internet bit nothing helped',
#  'message biffed rn send message previous message log chat showing unless directly message person even previous part conversation show weird bug',
#  'go hashtags want see recent post day algorithm think want see actually want see go recent top post showing post may july seems like algorithm understand recently mean obviously show recent post want see recent post chronological order please make filter option',
#  'instagram algorithm suck music never available region update make bug even worse seriously something abt algo buggy heck keep glitching able pin comment need edit comment option also big loser copycat trying copy reel competitor well yet fail terribly get life',
#  'everything fine long time recently instagram dark mode year issue past couple week whenever open instagram sometimes bright white never set light mode close reopen back dark mode go back forth sometimes tried turning dark mode worked little bit please fix asap',
#  'reason longer option share anything story reel watching let send friend dm want add post story original post made like taking picture otherwise option anymore reshape reel video story anymore',
#  ...]

# %%
Y
# Out:
# 0         3
# 1         2
# 2         5
# 3         2
# 4         3
#          ..
# 210537    2
# 210538    5
# 210539    5
# 210540    1
# 210541    5
# Name: rating, Length: 210542, dtype: int64

# %%
Y.value_counts()
# Out:
# 1    93177
# 5    40014
# 2    27373
# 3    26532
# 4    23446
# Name: rating, dtype: int64

# %%
a = {1:0,2:0,3:0,4:1,5:1}

# %%
Y = Y.map(a)

# %%
Y.head()
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    0
# Name: rating, dtype: int64

# %%
Y.value_counts()
# Out:
# 0    147082
# 1     63460
# Name: rating, dtype: int64

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vec = TfidfVectorizer(max_features = 5000, stop_words = 'english')
X_fit = vec.fit_transform(clean_data).toarray()
X_fit.shape
# Out:
# (210542, 5000)

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
model = MultinomialNB()

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_fit,Y, test_size = 0.3)

# %%
model.fit(X_train,Y_train)
# Out:
# MultinomialNB()

# %%
y_pred = model.predict(X_test)
from sklearn.metrics import classification_report,confusion_matrix
classification = classification_report(Y_test,y_pred)
print(classification)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.96      0.90     44123
#            1       0.86      0.59      0.70     19040
#
#     accuracy                           0.85     63163
#    macro avg       0.85      0.77      0.80     63163
# weighted avg       0.85      0.85      0.84     63163

# %%
print(confusion_matrix(Y_test,y_pred))
# Out:
# [[42292  1831]
#  [ 7843 11197]]
